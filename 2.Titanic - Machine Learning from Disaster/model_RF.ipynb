# %%
# 全部行都能輸出
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
train = pd.read_csv("./Data/output/train_ETL.csv")
test = pd.read_csv("./Data/output/test_ETL.csv")
train
test
# Out:
#      PassengerId  Pclass  Sex       Age  SibSp  Parch      Fare  Embarked  \
# 0              1       3    1  0.273456      1      0  0.014151         0
# 1              2       1    0  0.473882      1      0  0.139136         1
# 2              3       3    0  0.323563      0      0  0.015469         0
# 3              4       1    0  0.436302      1      0  0.103644         0
# 4              5       3    1  0.436302      0      0  0.015713         0
# ..           ...     ...  ...       ...    ...    ...       ...       ...
# 886          887       2    1  0.336089      0      0  0.025374         0
# 887          888       1    0  0.235876      0      0  0.058556         0
# 888          889       3    0  0.381000      1      2  0.045771         0
# 889          890       1    1  0.323563      0      0  0.058556         1
# 890          891       3    1  0.398722      0      0  0.015127         2
#
#      Title_name  Survived
# 0             1       0.0
# ...

# %%
# 刪除ID欄位
train_set = train.drop(columns="PassengerId", axis=1)
test_set = test.drop(columns="PassengerId", axis=1)
train_set
test_set
# Out:
#      Pclass  Sex       Age  SibSp  Parch      Fare  Embarked  Title_name  \
# 0         3    1  0.273456      1      0  0.014151         0           1
# 1         1    0  0.473882      1      0  0.139136         1           2
# 2         3    0  0.323563      0      0  0.015469         0           3
# 3         1    0  0.436302      1      0  0.103644         0           2
# 4         3    1  0.436302      0      0  0.015713         0           1
# ..      ...  ...       ...    ...    ...       ...       ...         ...
# 886       2    1  0.336089      0      0  0.025374         0           5
# 887       1    0  0.235876      0      0  0.058556         0           3
# 888       3    0  0.381000      1      2  0.045771         0           3
# 889       1    1  0.323563      0      0  0.058556         1           1
# 890       3    1  0.398722      0      0  0.015127         2           1
#
#      Survived
# 0         0.0
# 1         1.0
# 2         1.0
# 3         1.0
# ...

# %%
y = train_set["Survived"]
X = train_set.drop(columns="Survived", axis=1)

X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.9)

model = RandomForestClassifier(n_estimators=57, criterion="entropy", max_depth=6, min_samples_split=7, max_features="sqrt")
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print(accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=6, max_features='sqrt',
#                        min_samples_split=7, n_estimators=57)
# 0.800498753117207
# [[446  45]
#  [115 196]]

# %%
new_pred = model.predict(test_set)

sol_df = pd.DataFrame()

sol_df["PassengerId"] = test["PassengerId"]
sol_df["Survived"] = new_pred.astype(int)

sol_df
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         0
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
sol_df.to_csv("./Data/output/gender_submission.csv", index=False)
